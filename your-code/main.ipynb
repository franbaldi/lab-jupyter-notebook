# %% [markdown]
# # Introducing the amazing Francesco Baldissera

# %% [markdown]
# ## Purpose
# This notebook is intended for you to get to know Francesco a little bit better.

# %%
def name_input():
    print('Enter name:')
    x = input()
    print('Hello, ' + x)

# %% [markdown]
# ## Photo
# <img src="https://scontent-mad1-1.xx.fbcdn.net/v/t1.0-9/p720x720/44805148_10161123448815014_4234634868190871552_o.jpg?_nc_cat=111&_nc_sid=85a577&_nc_ohc=QcJMMQ0x9ikAX_B2XD-&_nc_ht=scontent-mad1-1.xx&_nc_tp=6&oh=98106d6bb0447b00e30d609045bbdf95&oe=5EB064EC" />

# %% [markdown]
# ## Francesco's Holiday Destination
#
# I've chosen to go back to Canaima National Park and re-explore it's natural beauties. Below you may find some of them:
#
# ## Angel's falls
# <iframe width="560" height="315" src="https://www.youtube.com/embed/L_tqK4eqelA" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
#
# ## Roraima Tepuy
#
# ![roraima-clouds.jpg](attachment:roraima-clouds.jpg)
#
# ## Some of my friends there
# ![Captura%20de%20Pantalla%202020-04-05%20a%20la%28s%29%2013.13.45.png](attachment:Captura%20de%20Pantalla%202020-04-05%20a%20la%28s%29%2013.13.45.png)
#
# I left Venezuela so I'm not in the photo :(

# %% [markdown]
# ## Top 3 things to do:
#
# - Hiking to the top of **Angel's Falls**
# - Slide down the _"El tobogán de la selva"_
# - Watch the best sunrise and sunset **ever**
